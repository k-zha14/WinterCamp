# %%
# 挂载google云硬盘
import os
from google.colab import drive
drive.mount('/content/gdrive')

# 更改工程的运行文件夹
os.chdir("/content/gdrive/My Drive/Colab Notebooks/")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pickle

with open("best_params.txt", "rb") as f:
    d = pickle.load(f)

print(d)
# Out:
# {'thresh': 2.0423832188246194, 'eps': 0.11885847364839468, 'min_samples': 6, 'weight': 0.6858433677155684, 'best_f1': 0.7001693410111576}

# %%
import json
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# 加载训练集
train_row_data_path = './Task2/train/train_author.json'
train_pub_data_path = './Task2/train/train_pub.json'

train_pub_data = json.load(open(train_pub_data_path, 'r', encoding='utf-8'))
train_data = json.load(open(train_row_data_path, 'r', encoding='utf-8'))

m_train_data = {}    # m 代表 Modify

## 将训练集进行转化，生成类似验证集的作者词典
for author in tqdm(list(train_data.keys())):
  m_train_data[author] = []
  clusters = train_data[author]
  for papers in clusters.values():
    m_train_data[author].extend(papers)


# 加载测试集
valid_row_data_path = './Task2/sna_data/sna_valid_author_raw.json'
valid_pub_data_path = './Task2/sna_data/sna_valid_pub.json'

valid_pub_data = json.load(open(valid_pub_data_path, 'r', encoding='utf-8'))
valid_data = json.load(open(valid_row_data_path, 'r', encoding='utf-8'))
# Out:
# 100%|██████████| 221/221 [00:00<00:00, 27907.31it/s]

# %%
# 数据预处理
import re

# 预处理名字
def precessName(name):
  name = name.strip()
  name = re.sub(r'\s', ' ', name)
  name = name.lower().replace(' ', '_')
  name = name.replace('.', '_')
  name = name.replace('-', '')
  name = re.sub(r"_{2,}", "_", name)    # 两个及其以上的下划线用一个下划线代替
  return name

# 预处理机构,简写替换，
def preprocessOrg(org):
  if org != "":
    org = org.replace('Sch.', 'School')
    org = org.replace('Dept.', 'Department')
    org = org.replace('Coll.', 'College')
    org = org.replace('Inst.', 'Institute')
    org = org.replace('Univ.', 'University')
    org = org.replace('Lab ', 'Laboratory ')
    org = org.replace('Lab.', 'Laboratory')
    org = org.replace('Natl.', 'National')
    org = org.replace('Comp.', 'Computer')
    org = org.replace('Sci.', 'Science')
    org = org.replace('Tech.', 'Technology')
    org = org.replace('Technol.', 'Technology')
    org = org.replace('Elec.', 'Electronic')
    org = org.replace('Engr.', 'Engineering')
    org = org.replace('Aca.', 'Academy')
    org = org.replace('Syst.', 'Systems')
    org = org.replace('Eng.', 'Engineering')
    org = org.replace('Res.', 'Research')
    org = org.replace('Appl.', 'Applied')
    org = org.replace('Chem.', 'Chemistry')
    org = org.replace('Prep.', 'Petrochemical')
    org = org.replace('Phys.', 'Physics')
    org = org.replace('Phys.', 'Physics')
    org = org.replace('Mech.', 'Mechanics')
    org = org.replace('Mat.', 'Material')
    org = org.replace('Cent.', 'Center')
    org = org.replace('Ctr.', 'Center')
    org = org.replace('Behav.', 'Behavior')
    org = org.replace('Atom.', 'Atomic')
    org = org.split(';')[0]  # 多个机构只取第一个
  return org

#正则去标点
def etl(content):
  content = content.lower().strip()        # 统一大小写
  content = re.sub('[:-]+', ' ', content)    # 替换爬虫的连续空格标记
  content = re.sub("[\s+\.\!\/,;$%^*(+\"\')]+|[+——()?【】“”！，。？、~@#￥%……&*（）]+", " ", content)
  content = re.sub(r" {2,}", " ", content)
  return content

# 将train_pub_data或valid_pub_data转换格式，提出author和org
def formatTransfer(pub_data):
  for p_id in pub_data:
    authors = pub_data[p_id]['authors']
    rep_dict = {}
    for author in authors:
      name = author['name']
      org = author['org'] if 'org' in author else ''
      rep_dict[name] = org
    pub_data[p_id]['authors'] = rep_dict

# %%
# 转换pub_data格式
formatTransfer(train_pub_data)

for item_dict in train_pub_data.items():
  print(item_dict[0])
  for item in item_dict[1].items():
    print(item)
  break
# Out:
# P9a1gcvg
# ('authors', {'Fenghe Qiu': 'Institute of Pharmacology and Toxicology', 'Li Liu': 'Institute of Pharmacology and Toxicology', 'Li Guo': 'Institute of Pharmacology and Toxicology'})
# ('title', 'Rapid determination of central nervous drugs in plasma by solid-phase extraction and GC-FID and GC-MS')
# ('abstract', 'Objective: To establish a simultaneous determination method of central nervous drugs including barbitals, benzodiazepines, phenothiozines and tricyclic antidepressants in human plasma. Methods: Drugs in plasma were extracted and purified by using X-5 resin solid phase extraction columns, followed by identification and quantitation using capillary GC-FID and GC-MS. Results: More than 20 drugs were simultaneously extracted from human plasma, and effectively separated in GC and TIC spectra. The correlation coefficient of standard curves was larger than 0.99, and relative standard differences (RSD) were less than 10% for most of the drugs. Under neutral extraction conditions, the lowest detection limits of barbitals were in the range of 2 ~ 5 μg/ml, in optimized conditions, they were reduced to 0.3 ~ 0.5 μg/ml. Conclusion: X-5 resin solid-phase extraction is fit for the simultaneous extraction and purification of large number of drugs in plasma, therefore it is satisfactory for rapid determination of overdose drugs clinically, when combined with capillary GC and GC-MS.')
# ('keywords', ['central nervous drugs', 'GC-FID', 'GC-MS', 'solid-phase extraction', 'X-5 resin'])
# ('venue', 'Chinese Pharmaceutical Journal')
# ('year', 1996)
# ('id', 'P9a1gcvg')

# %%
# load wordMatrix, 加载预训练的词向量
import io

def load_vectors(fname):
  fin = io.open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
  n, d = map(int, fin.readline().split())
  print('Total numbers:', n, 'Dimension:', d)
  data = {}
  for i, line in enumerate(fin):
    tokens = line.rstrip().split(' ')
    data[tokens[0]] = list(map(float, tokens[1:]))    
    # 根据FastText文档，序列化储存的字符以实际出现的频次排列，高频1W词大致够用
    if i == int(2.5e5):
      break
  return data

# word2vector, 转化函数
def word2vector(word, vocabulary, wordMatrix, lost_words):
  r_arr = np.zeros(300)
  if word in vocabulary:
    try:
      r_arr = np.array(wordMatrix[word])
    except KeyError:    # 找不到对应词向量
      lost_words.append(word)
      return r_arr
  return r_arr

# 加载预训练词向量
pretrained_fastText_path = './Task2/wiki-news-300d-1M.vec'
wordMatrix = load_vectors(pretrained_fastText_path)
print('Actual Loaded words:', len(wordMatrix))
# Out:
# Total numbers: 999994 Dimension: 300
# Actual Loaded words: 250001

# %%
print(len(train_pub_data))
# Out:
# 203184

# %% [markdown]
# #### 根据训练集的label构建训练对，训练二分类器，从而提取特征

# %%
from functools import reduce
from tqdm import tqdm_notebook
import math
import random

# 1).构造训练集pairs
def get_label(paper_author_dict, id_i, id_j):
    if paper_author_dict[id_i] == paper_author_dict[id_j]:
        return 1
    return 0

def gen_train_data(train_data):
  pairs = []
  for i, author in tqdm_notebook(enumerate(train_data), total=len(train_data)):
    papers = [p_id for author_id in train_data[author] for p_id in train_data[author][author_id]]    # 从train训练集中直接提取出所有paper ids
    # 空文本集
    if (len(papers) == 0):
      continue
    
    paper_author_dict = {p_id: author_id for author_id in train_data[author] for p_id in train_data[author][author_id]}    # 建立从p_id到author_id的映射

    sasn = []    # 正样本集
    dasn = []    # 负样本集

    # 产生索引pair, 偏移1个单位（不包含对角线）
    for i, j in zip(*np.triu_indices(len(papers), k=1)): 
        p_i = papers[i]
        p_j = papers[j]

        # 标签
        label = get_label(paper_author_dict, p_i, p_j)
        if label == 0:
            dasn.append((p_i, p_j, 0))
        else:
            sasn.append((p_i, p_j, 1))

    # 进行降采样，解决正负样本不平衡
    category_size = len(sasn)
    all_pairs = map(lambda x: int(math.ceil(category_size / float(len(x)))) * x, [sasn, dasn])
    pairs.extend(reduce(lambda x, y: x + random.sample(y, int(category_size)), all_pairs, []))

  return pairs

pairs = gen_train_data(train_data)
# Out:
# HBox(children=(IntProgress(value=0, max=221), HTML(value='')))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 2).提取特征训练相似度模型
corpus = []
for p_id in tqdm_notebook(train_pub_data):
  paper = train_pub_data[p_id]
  title = paper['title'] if 'title' in paper else ''
  # abstract = paper['abstract'] if 'abstract' in paper else ''
  keywords = ' '.join(paper['keywords']) if 'keywords' in paper else ''
  # semantic_feature = title + ' ' + keywords + ' ' + abstract
  semantic_feature = title + ' ' + keywords
  semantic_feature = etl(semantic_feature)    # 去除句中标点，并进行分词
  corpus.append(semantic_feature)

stop_words = ['based','for','and','using','with','the', 'are','can']
tfidf_model = TfidfVectorizer(token_pattern=r"(?u)\b\w\w\w+\b", stop_words=stop_words).fit(corpus)
vocabulary = list(tfidf_model.vocabulary_.keys())

import torch

# 3).预测验证集相似度矩阵



# 4).聚类消歧
# Out:
# HBox(children=(IntProgress(value=0, max=203184), HTML(value='')))

# %%
from sklearn.cluster import DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer

res_dict = {}    # 储存分类结果
for author in tqdm_notebook(m_train_data):
  p_ids = m_train_data[author]
  corpus = []         # 储存在同一个作者下的所有语料
  coauther_orgs = []  # 储存所有机构和共同作者信息

  if(len(p_ids) == 0):
    res_dict[author] = []
    continue

  for p_id in p_ids:
    paper = train_pub_data[p_id]
    title = paper['title'] if 'title' in paper else ''
    # abstract = paper['abstract'] if 'abstract' in paper else ''
    keywords = ' '.join(paper['keywords']) if 'keywords' in paper else ''
    # semantic_feature = title + ' ' + keywords + ' ' + abstract
    semantic_feature = title + ' ' + keywords
    semantic_feature = etl(semantic_feature)    # 去除句中标点，并进行分词
    corpus.append(semantic_feature)
    # 作者和机构信息
    authors = paper['authors'].keys()
    names = [precessName(paper_author) for paper_author in authors]
    orgs = [preprocessOrg(org) for org in paper['authors'].values() if org != ''] 
    abstract = paper["abstract"] if ('abstract' in paper and paper["abstract"] is not None) else ''
    try:
      coauther_orgs.append(etl(' '.join(names + orgs) + ' '+ abstract))   
    except TypeError:
      print(p_id, names, orgs, abstract)      
  co_vec = TfidfVectorizer().fit_transform(coauther_orgs).todense()

  # 删除两个字母及以下的词（多为介词），加入stopwords列表
  stop_words = ['based','for','and','using','with','the', 'are','can']
  tfidf_model = TfidfVectorizer(token_pattern=r"(?u)\b\w\w\w+\b", stop_words=stop_words).fit(corpus)
  vocabulary = list(tfidf_model.vocabulary_.keys())
  
  corpus_vec = []
  lost_words = []
  # Tokenize, 将语义文本转化为语义向量
  unvalid_sample = 0
  for i, sample in enumerate(corpus):
    text_vector = np.zeros(300)
    valid_word_count = 0
    words = set(sample.split())    # 去重

    for word in words:
      tmp_arr = word2vector(word, vocabulary, wordMatrix, lost_words)
      if(np.sum(np.abs(tmp_arr))!=0):
        valid_word_count += 1
      text_vector = text_vector + tmp_arr

    if(np.sum(np.abs(text_vector)) == 0):
      unvalid_sample += 1
    
    # 求平均，防止devide by 0, TFIDF加权则可以不用
    # text_vector = text_vector/valid_word_count if (valid_word_count!=0) else text_vector
    corpus_vec.append(text_vector)

  corpus_vec = np.array(corpus_vec)
  
  # 拼接一下
  corpus_vec = np.concatenate((corpus_vec, co_vec), axis=1)
  clf = DBSCAN(eps=0.07, min_samples=4, metric='cosine')
  s = clf.fit_predict(corpus_vec)

  paper_dict = {}
  for label, p_id in zip(clf.labels_, p_ids):
      if str(label) not in paper_dict:
          paper_dict[str(label)] = [p_id]
      else:
          paper_dict[str(label)].append(p_id)
  res_dict[author] = list(paper_dict.values())

## Output Info

  print('Name:', author, end=', ')
  print('Unvalid:', unvalid_sample, end='; ')
  print('Lost words:', len(lost_words))
  print('num of clusters:', len(paper_dict))
# Out:
# HBox(children=(IntProgress(value=0, max=221), HTML(value='')))
# Name: li_guo, Unvalid: 1; Lost words: 1977
# num of clusters: 14
# Name: bo_shen, Unvalid: 3; Lost words: 2876
# num of clusters: 31
# Name: di_wang, Unvalid: 1; Lost words: 2293
# num of clusters: 22
# Name: long_wang, Unvalid: 0; Lost words: 560
# num of clusters: 10
# Name: qiang_xu, Unvalid: 1; Lost words: 2143
# num of clusters: 25
# Name: xiang_wang, Unvalid: 0; Lost words: 2344
# num of clusters: 19
# Name: changming_liu, Unvalid: 0; Lost words: 177
# num of clusters: 3
# Name: kenji_kaneko, Unvalid: 0; Lost words: 136
# num of clusters: 4
# Name: guohua_chen, Unvalid: 0; Lost words: 1431
# num of clusters: 19
# Name: hai_jin, Unvalid: 0; Lost words: 75
# num of clusters: 2
# Name: jia_li, Unvalid: 0; Lost words: 721
# num of clusters: 8
# Name: guoliang_li, Unvalid: 0; Lost words: 1016
# num of clusters: 14
# Name: lan_wang, Unvalid: 0; Lost words: 1699
# num of clusters: 18
# Name: alessandro_giuliani, Unvalid: 0; Lost words: 317
# num of clusters: 9
# Name: jiang_he, Unvalid: 1; Lost words: 463
# num of clusters: 10
# Name: xiang_gao, Unvalid: 3; Lost words: 2596
# num of clusters: 24
# Name: jianping_wu, Unvalid: 0; Lost words: 375
# num of clusters: 3
# Name: peng_shi, Unvalid: 0; Lost words: 1104
# num of clusters: 4
# Name: feng_wu, Unvalid: 4; Lost words: 2865
# num of clusters: 26
# Name: jing_zhu, Unvalid: 0; Lost words: 803
# num of clusters: 14
# Name: xiaoyang_zhang, Unvalid: 1; Lost words: 768
# num of clusters: 10
# Name: mei_han, Unvalid: 0; Lost words: 689
# num of clusters: 9
# Name: jianhua_shen, Unvalid: 0; Lost words: 575
# num of clusters: 12
# Name: hong_xiao, Unvalid: 0; Lost words: 1487
# num of clusters: 15
# Name: qing_yang, Unvalid: 2; Lost words: 3324
# num of clusters: 34
# Name: makoto_sasaki, Unvalid: 2; Lost words: 418
# num of clusters: 3
# Name: feng_gao, Unvalid: 0; Lost words: 4009
# num of clusters: 40
# Name: d_zhang, Unvalid: 0; Lost words: 295
# num of clusters: 8
# Name: akira_ono, Unvalid: 0; Lost words: 261
# num of clusters: 3
# Name: hong_yang, Unvalid: 0; Lost words: 313
# num of clusters: 8
# Name: bin_gao, Unvalid: 0; Lost words: 447
# num of clusters: 9
# Name: t_wang, Unvalid: 1; Lost words: 1756
# num of clusters: 9
# Name: qing_liu, Unvalid: 5; Lost words: 3436
# num of clusters: 44
# Name: ping_sheng, Unvalid: 0; Lost words: 246
# num of clusters: 8
# Name: j_huang, Unvalid: 0; Lost words: 175
# num of clusters: 2
# Name: chao_yuan, Unvalid: 0; Lost words: 948
# num of clusters: 4
# Name: jianyong_wang, Unvalid: 0; Lost words: 214
# num of clusters: 4
# Name: hong_yan_wang, Unvalid: 0; Lost words: 165
# num of clusters: 1
# Name: xi_liu, Unvalid: 1; Lost words: 1101
# num of clusters: 12
# Name: jing_chen, Unvalid: 1; Lost words: 5450
# num of clusters: 45
# Name: bo_zhou, Unvalid: 1; Lost words: 2226
# num of clusters: 25
# Name: bin_yao, Unvalid: 0; Lost words: 2593
# num of clusters: 15
# Name: ping_yang, Unvalid: 0; Lost words: 809
# num of clusters: 10
# Name: jianchao_yang, Unvalid: 0; Lost words: 171
# num of clusters: 4
# Name: f_liu, Unvalid: 2; Lost words: 1806
# num of clusters: 23
# Name: minhua_jiang, Unvalid: 0; Lost words: 96
# num of clusters: 2
# Name: j_lin, Unvalid: 2; Lost words: 1034
# num of clusters: 11
# Name: hong_li, Unvalid: 3; Lost words: 4212
# num of clusters: 53
# Name: ke_li, Unvalid: 0; Lost words: 171
# num of clusters: 3
# Name: jing_deng, Unvalid: 0; Lost words: 665
# num of clusters: 5
# Name: xin_li, Unvalid: 2; Lost words: 5945
# num of clusters: 41
# Name: xin_wu, Unvalid: 1; Lost words: 1024
# num of clusters: 9
# Name: alexander_belyaev, Unvalid: 1; Lost words: 154
# num of clusters: 3
# Name: chen_liu, Unvalid: 0; Lost words: 1355
# num of clusters: 9
# Name: di_wu, Unvalid: 6; Lost words: 3605
# num of clusters: 38
# Name: xiao_liu, Unvalid: 0; Lost words: 1996
# num of clusters: 21
# Name: bin_zhao, Unvalid: 4; Lost words: 2715
# num of clusters: 32
# Name: qian_chen, Unvalid: 1; Lost words: 1891
# num of clusters: 21
# Name: chao_zhang, Unvalid: 0; Lost words: 369
# num of clusters: 3
# Name: w_huang, Unvalid: 0; Lost words: 763
# num of clusters: 4
# Name: ning_li, Unvalid: 1; Lost words: 2410
# num of clusters: 31
# Name: kai_sun, Unvalid: 1; Lost words: 325
# num of clusters: 6
# Name: feng_zhao, Unvalid: 1; Lost words: 2180
# num of clusters: 25
# Name: hao_huang, Unvalid: 2; Lost words: 1919
# num of clusters: 25
# Name: israel_goldberg, Unvalid: 5; Lost words: 313
# num of clusters: 3
# Name: hui_wei, Unvalid: 0; Lost words: 1016
# num of clusters: 5
# Name: yajun_guo, Unvalid: 0; Lost words: 205
# num of clusters: 3
# Name: jianfeng_gao, Unvalid: 0; Lost words: 124
# num of clusters: 3
# Name: xue_wang, Unvalid: 0; Lost words: 1549
# num of clusters: 11
# Name: lei_zhao, Unvalid: 0; Lost words: 449
# num of clusters: 5
# Name: meng_wang, Unvalid: 0; Lost words: 556
# num of clusters: 10
# Name: yuanyuan_liu, Unvalid: 1; Lost words: 893
# num of clusters: 6
# Name: dongsheng_wang, Unvalid: 0; Lost words: 1129
# num of clusters: 8
# Name: qian_zhang, Unvalid: 0; Lost words: 1462
# num of clusters: 14
# Name: koji_fujita, Unvalid: 0; Lost words: 133
# num of clusters: 1
# Name: changhong_wang, Unvalid: 0; Lost words: 566
# num of clusters: 6
# Name: heqing_huang, Unvalid: 0; Lost words: 219
# num of clusters: 4
# Name: weiguo_fan, Unvalid: 0; Lost words: 253
# num of clusters: 5
# Name: jianping_fan, Unvalid: 1; Lost words: 235
# num of clusters: 6
# Name: yan_liang, Unvalid: 1; Lost words: 1718
# num of clusters: 20
# Name: l_sun, Unvalid: 0; Lost words: 234
# num of clusters: 7
# Name: liang_wang, Unvalid: 0; Lost words: 578
# num of clusters: 7
# Name: s_huang, Unvalid: 0; Lost words: 618
# num of clusters: 3
# Name: jinlong_yang, Unvalid: 0; Lost words: 462
# num of clusters: 3
# Name: jian_wang, Unvalid: 1; Lost words: 6095
# num of clusters: 53
# Name: tao_jiang, Unvalid: 0; Lost words: 1374
# num of clusters: 17
# Name: jing_gao, Unvalid: 0; Lost words: 1701
# num of clusters: 20
# Name: feng_li, Unvalid: 0; Lost words: 2150
# num of clusters: 22
# Name: lin_zhong, Unvalid: 0; Lost words: 154
# num of clusters: 3
# Name: fang_wang, Unvalid: 1; Lost words: 4254
# num of clusters: 38
# Name: liang_li, Unvalid: 0; Lost words: 452
# num of clusters: 9
# Name: c_c_lin, Unvalid: 0; Lost words: 144
# num of clusters: 4
# Name: wen_tan, Unvalid: 1; Lost words: 509
# num of clusters: 7
# Name: xing_liu, Unvalid: 2; Lost words: 1425
# num of clusters: 11
# Name: feng_zhu, Unvalid: 0; Lost words: 1420
# num of clusters: 20
# Name: jian_zhou, Unvalid: 1; Lost words: 1929
# num of clusters: 24
# Name: shuai_zhang, Unvalid: 1; Lost words: 1590
# num of clusters: 19
# Name: juan_liu, Unvalid: 0; Lost words: 125
# num of clusters: 3
# Name: li_jiang, Unvalid: 1; Lost words: 2102
# num of clusters: 17
# Name: yong_yu, Unvalid: 0; Lost words: 1247
# num of clusters: 22
# Name: bing_chen, Unvalid: 0; Lost words: 674
# num of clusters: 11
# Name: liang_han, Unvalid: 0; Lost words: 476
# num of clusters: 8
# Name: jin_zhang, Unvalid: 3; Lost words: 3581
# num of clusters: 39
# Name: tao_zhou, Unvalid: 0; Lost words: 561
# num of clusters: 9
# Name: jie_zhang, Unvalid: 0; Lost words: 1757
# num of clusters: 29
# Name: xiaoping_wu, Unvalid: 0; Lost words: 646
# num of clusters: 9
# Name: jianguo_liu, Unvalid: 0; Lost words: 2067
# num of clusters: 32
# Name: liping_liu, Unvalid: 0; Lost words: 73
# num of clusters: 2
# Name: song_gao, Unvalid: 0; Lost words: 1744
# num of clusters: 9
# Name: di_zhang, Unvalid: 0; Lost words: 1062
# num of clusters: 14
# Name: yue_wang, Unvalid: 2; Lost words: 3111
# num of clusters: 24
# Name: jianmin_zhao, Unvalid: 0; Lost words: 238
# num of clusters: 5
# Name: jianjun_liu, Unvalid: 1; Lost words: 1071
# num of clusters: 17
# Name: rakesh_kumar, Unvalid: 0; Lost words: 1215
# num of clusters: 9
# Name: yu_gu, Unvalid: 0; Lost words: 831
# num of clusters: 10
# Name: jin_luo, Unvalid: 0; Lost words: 636
# num of clusters: 6
# Name: shaobin_wang, Unvalid: 0; Lost words: 40
# num of clusters: 3
# Name: jin_he, Unvalid: 0; Lost words: 1191
# num of clusters: 11
# Name: hui_yu, Unvalid: 1; Lost words: 1716
# num of clusters: 21
# Name: lei_chen, Unvalid: 0; Lost words: 1040
# num of clusters: 15
# Name: wenjie_shen, Unvalid: 0; Lost words: 516
# num of clusters: 7
# Name: fei_qi, Unvalid: 0; Lost words: 279
# num of clusters: 4
# Name: xiaoming_liu, Unvalid: 0; Lost words: 582
# num of clusters: 4
# Name: shu_tao, Unvalid: 0; Lost words: 547
# num of clusters: 10
# Name: j_ma, Unvalid: 1; Lost words: 133
# num of clusters: 1
# Name: weidong_li, Unvalid: 1; Lost words: 1612
# num of clusters: 16
# Name: d_li, Unvalid: 2; Lost words: 334
# num of clusters: 4
# Name: haiying_wang, Unvalid: 0; Lost words: 256
# num of clusters: 2
# Name: dan_wu, Unvalid: 0; Lost words: 1233
# num of clusters: 11
# Name: akio_kobayashi, Unvalid: 0; Lost words: 294
# num of clusters: 4
# Name: baoli_zhu, Unvalid: 0; Lost words: 122
# num of clusters: 1
# Name: li_ma, Unvalid: 0; Lost words: 3557
# num of clusters: 25
# Name: y_feng, Unvalid: 0; Lost words: 765
# num of clusters: 7
# Name: z_zhou, Unvalid: 0; Lost words: 878
# num of clusters: 4
# Name: huan_liu, Unvalid: 0; Lost words: 474
# num of clusters: 10
# Name: furong_gao, Unvalid: 0; Lost words: 173
# num of clusters: 4
# Name: chuan_he, Unvalid: 0; Lost words: 989
# num of clusters: 10
# Name: lin_xu, Unvalid: 0; Lost words: 789
# num of clusters: 6
# Name: jianxin_shi, Unvalid: 0; Lost words: 352
# num of clusters: 2
# Name: hao_yan, Unvalid: 0; Lost words: 206
# num of clusters: 4
# Name: liu_yang, Unvalid: 2; Lost words: 2395
# num of clusters: 23
# Name: j_jiang, Unvalid: 0; Lost words: 184
# num of clusters: 3
# Name: liang_liu, Unvalid: 0; Lost words: 2069
# num of clusters: 21
# Name: hong_liu, Unvalid: 6; Lost words: 5411
# num of clusters: 51
# Name: kui_ren, Unvalid: 0; Lost words: 124
# num of clusters: 2
# Name: jing_wu, Unvalid: 0; Lost words: 392
# num of clusters: 8
# Name: dong_xu, Unvalid: 2; Lost words: 1012
# num of clusters: 10
# Name: huan_yang, Unvalid: 0; Lost words: 1263
# num of clusters: 13
# Name: lihua_xie, Unvalid: 0; Lost words: 74
# num of clusters: 2
# Name: guochun_zhao, Unvalid: 0; Lost words: 1195
# num of clusters: 4
# Name: li_zhou, Unvalid: 0; Lost words: 310
# num of clusters: 5
# Name: jie_lin, Unvalid: 0; Lost words: 438
# num of clusters: 5
# Name: guanghua_li, Unvalid: 1; Lost words: 1203
# num of clusters: 12
# Name: feng_liu, Unvalid: 0; Lost words: 4524
# num of clusters: 31
# Name: hong_mei, Unvalid: 0; Lost words: 372
# num of clusters: 3
# Name: xiaodong_he, Unvalid: 0; Lost words: 1052
# num of clusters: 12
# Name: hong_cheng, Unvalid: 0; Lost words: 879
# num of clusters: 8
# Name: zhi_gang_zhang, Unvalid: 2; Lost words: 664
# num of clusters: 9
# Name: c_c_wang, Unvalid: 1; Lost words: 850
# num of clusters: 15
# Name: lei_jiang, Unvalid: 1; Lost words: 2434
# num of clusters: 21
# Name: shan_gao, Unvalid: 76; Lost words: 3097
# num of clusters: 39
# Name: chenguang_wang, Unvalid: 0; Lost words: 187
# num of clusters: 3
# Name: jie_xiao, Unvalid: 1; Lost words: 746
# num of clusters: 3
# Name: li_li_wang, Unvalid: 1; Lost words: 96
# num of clusters: 2
# Name: bo_zhang, Unvalid: 0; Lost words: 5420
# num of clusters: 47
# Name: bin_zhang, Unvalid: 0; Lost words: 1007
# num of clusters: 16
# Name: ji_zhang, Unvalid: 1; Lost words: 519
# num of clusters: 8
# Name: cheng_yang, Unvalid: 0; Lost words: 1925
# num of clusters: 21
# Name: weiping_cai, Unvalid: 0; Lost words: 449
# num of clusters: 6
# Name: gang_pan, Unvalid: 0; Lost words: 258
# num of clusters: 4
# Name: xi_li, Unvalid: 1; Lost words: 1912
# num of clusters: 26
# Name: guoqing_hu, Unvalid: 0; Lost words: 432
# num of clusters: 9
# Name: jianguo_hou, Unvalid: 0; Lost words: 527
# num of clusters: 10
# Name: haijiang_wang, Unvalid: 0; Lost words: 327
# num of clusters: 7
# Name: bing_zhao, Unvalid: 9; Lost words: 2047
# num of clusters: 16
# Name: wei_chen, Unvalid: 2; Lost words: 2633
# num of clusters: 20
# Name: jianfeng_chen, Unvalid: 0; Lost words: 388
# num of clusters: 2
# Name: wei_zheng, Unvalid: 2; Lost words: 3537
# num of clusters: 33
# Name: juan_chen, Unvalid: 0; Lost words: 242
# num of clusters: 4
# Name: guang_yang, Unvalid: 1; Lost words: 223
# num of clusters: 3
# Name: hong_zhao, Unvalid: 5; Lost words: 2884
# num of clusters: 36
# Name: chao_deng, Unvalid: 0; Lost words: 1518
# num of clusters: 15
# Name: fei_liu, Unvalid: 0; Lost words: 338
# num of clusters: 6
# Name: cheng_zhu, Unvalid: 0; Lost words: 667
# num of clusters: 5
# Name: min_sun, Unvalid: 0; Lost words: 1284
# num of clusters: 9
# Name: hui_wang, Unvalid: 4; Lost words: 8502
# num of clusters: 83
# Name: chao_chen, Unvalid: 0; Lost words: 933
# num of clusters: 11
# Name: gang_zhang, Unvalid: 1; Lost words: 1723
# num of clusters: 23
# Name: xiaoming_li, Unvalid: 0; Lost words: 2468
# num of clusters: 33
# Name: chunxia_li, Unvalid: 0; Lost words: 555
# num of clusters: 9
# Name: wenjun_zheng, Unvalid: 0; Lost words: 425
# num of clusters: 4
# Name: bo_jiang, Unvalid: 0; Lost words: 3012
# num of clusters: 25
# Name: hideaki_takahashi, Unvalid: 0; Lost words: 81
# num of clusters: 3
# Name: kai_yu, Unvalid: 0; Lost words: 179
# num of clusters: 3
# Name: changsheng_li, Unvalid: 1; Lost words: 551
# num of clusters: 8
# Name: peng_gong, Unvalid: 0; Lost words: 245
# num of clusters: 2
# Name: hongbo_sun, Unvalid: 0; Lost words: 513
# num of clusters: 3
# Name: jie_yin, Unvalid: 3; Lost words: 1628
# num of clusters: 13
# Name: z_wu, Unvalid: 1; Lost words: 1048
# num of clusters: 9
# Name: zhi_wang, Unvalid: 2; Lost words: 3113
# num of clusters: 38
# Name: lixia_zhang, Unvalid: 0; Lost words: 677
# num of clusters: 6
# Name: qiong_luo, Unvalid: 0; Lost words: 295
# num of clusters: 8
# Name: s_liu, Unvalid: 1; Lost words: 2010
# num of clusters: 4
# Name: jin_li, Unvalid: 0; Lost words: 2868
# num of clusters: 27
# Name: jing_li, Unvalid: 4; Lost words: 6999
# num of clusters: 67
# Name: c_yang, Unvalid: 0; Lost words: 981
# num of clusters: 9
# Name: yuxi_liu, Unvalid: 0; Lost words: 423
# num of clusters: 5
# Name: bing_zhang, Unvalid: 0; Lost words: 1533
# num of clusters: 17
# Name: j_y_wang, Unvalid: 1; Lost words: 238
# num of clusters: 1
# Name: sheng_dai, Unvalid: 0; Lost words: 622
# num of clusters: 4
# Name: jie_luo, Unvalid: 0; Lost words: 1147
# num of clusters: 12
# Name: bin_hu, Unvalid: 0; Lost words: 3370
# num of clusters: 27
# Name: hai_yang, Unvalid: 0; Lost words: 109
# num of clusters: 3
# Name: ming_chen, Unvalid: 3; Lost words: 4020
# num of clusters: 44
# Name: juan_du, Unvalid: 0; Lost words: 326
# num of clusters: 3
# Name: hiroaki_okamoto, Unvalid: 0; Lost words: 355
# num of clusters: 5
# Name: dan_wang, Unvalid: 0; Lost words: 228
# num of clusters: 9
# Name: jun_chen, Unvalid: 1; Lost words: 5481
# num of clusters: 42
# Name: bai_yang, Unvalid: 0; Lost words: 963
# num of clusters: 10
# Name: hiroshi_sakamoto, Unvalid: 0; Lost words: 426
# num of clusters: 5

# %%
tt = np.concatenate((corpus_vec, co_vec), axis=1)
print(co_vec.shape)
print(tt.shape)
# Out:
# (1464, 18695)
# (1464, 18995)

# %%
# 这里主要试一下直接抽取TF-IDF特征在数据集上的表现
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm import tqdm_notebook

def disambiguate_by_cluster(input_data, pub_data):
  res_dict = {}
  for author in tqdm_notebook(input_data):
    coauther_orgs = []
    p_ids = input_data[author]
    if len(p_ids) == 0:
      res_dict[author] = []
      continue

    paper_dict = {}
    for p_id in p_ids:
      paper = pub_data[p_id]
      authors = paper['authors'].keys()
      names = [precessName(paper_author) for paper_author in authors]
      orgs = [preprocessOrg(org) for org in paper['authors'].values() if org != ''] 
      # abstract = paper["abstract"] if ('abstract' in paper and paper["abstract"] is not None) else ''
      title = paper['title'] if 'title' in paper and paper['title'] is not None else ''
      keywords = paper['keywords'] if 'keywords' in paper else []
      year = str(paper['year']) if 'year' in paper and paper['year'] is not None else ''
      venue = paper['venue'] if 'venue' in paper and paper['venue'] is not None else '' 
      
      try:
        coauther_orgs.append(etl(' '.join(names + orgs) + ' '.join(keywords) + ' '+ title+ ' '+ str(year) + ' ' + venue))   
      except TypeError:
        print(p_id, names, orgs, abstract)      
    tfidf = TfidfVectorizer().fit_transform(coauther_orgs)
    # sim_mertric = pairwise_distances(tfidf, metric='cosine')

    clf = DBSCAN(metric='cosine', min_samples=3)
    s = clf.fit_predict(tfidf)
    #每个样本所属的簇
    for label, p_id in zip(clf.labels_, p_ids):
      paper = pub_data[p_id]
      if str(label) not in paper_dict:
        paper_dict[str(label)] = [paper['id']]
      else:
        paper_dict[str(label)].append(paper['id'])
    res_dict[author] = list(paper_dict.values())

  return res_dict

res_dict = disambiguate_by_cluster(m_train_data, train_pub_data)
# Out:
# HBox(children=(IntProgress(value=0, max=221), HTML(value='')))

# %%
avg_num_clusters = np.sum([len(res_dict[author]) for author in res_dict])/len(res_dict)
print('Average cluster number of per author:', avg_num_clusters)
# Out:
# Average cluster number of per author: 17.846153846153847

# %% [markdown]
# ### Pair-wise F1 评估函数

# %%
from tqdm import tqdm_notebook

# 评估论文对
def evaluate_fun(correct_labels, pred_labels):
  TP = 0.0  # Pairs Correctly Predicted To SameAuthor
  TP_FP = 0.0  # Total Pairs Predicted To SameAuthor
  TP_FN = 0.0  # Total Pairs To SameAuthor

  for i in range(len(correct_labels)):
    for j in range(i + 1, len(correct_labels)):
      if correct_labels[i] == correct_labels[j]:
        TP_FN += 1
      if pred_labels[i] == pred_labels[j]:
        TP_FP += 1
      if (correct_labels[i] == correct_labels[j]) and (pred_labels[i] == pred_labels[j]):
        TP += 1

  if TP == 0:
    pairwise_precision = 0
    pairwise_recall = 0
    pairwise_f1 = 0
  else:
    pairwise_precision = TP / TP_FP
    pairwise_recall = TP / TP_FN
    pairwise_f1 = (2 * pairwise_precision * pairwise_recall) / (pairwise_precision + pairwise_recall)

  return pairwise_precision, pairwise_recall, pairwise_f1


# 评估作者
def evaluate_author(correct_clusters, pred_clusters):
  dict_array = {}
  for i, author_id in enumerate(correct_clusters):
    for p_id in correct_clusters[author_id]:
      dict_array[p_id] = i
  
  correct_labels = list(dict_array.values())

  ## 重值键值，聚类方法不同，未必论文集能全回收
  for p_id in dict_array:
    dict_array[p_id] = -1

  for i, cluster in enumerate(pred_clusters):
    for p_id in cluster:
      dict_array[p_id] = i
  
  pred_labels = list(dict_array.values())

  author_precision, author_recall, author_f1 = evaluate_fun(correct_labels, pred_labels)
  return author_f1

# 进行测试

f1_results = []

for author in tqdm_notebook(train_data):
  clusters = train_data[author]
  pred_clusters = res_dict[author]
  f1_score = evaluate_author(clusters, pred_clusters)
  f1_results.append(f1_score)

f1_score = np.mean(f1_results)
print('Final results: ', f1_score)
# Out:
# HBox(children=(IntProgress(value=0, max=221), HTML(value='')))
# Final results:  0.3295689008444801

# %%
# 对离散论文集出力，规则匹配+近似
import difflib

name_list = ['z_z_chen','b_shen','ruiquan_zhang','x_y_zhang','kongzhang_yang','hongzhuan_chen','pinhsun_chen','l_zang']

difflib.get_close_matches('shen_bo',name_list, n=1)
# Out:
# ['b_shen']

# %% [markdown]
# #### 从FastText官网下载预训练的词向量

# %%
# !wget "https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip"
# !unzip wiki-news-300d-1M.vec.zip -d ./Task2/
# Out:
# --2020-02-20 09:55:55--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.20.22.166, 104.20.6.166, 2606:4700:10::6814:16a6, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.20.22.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681808098 (650M) [application/zip]
# Saving to: ‘wiki-news-300d-1M.vec.zip’
#
# wiki-news-300d-1M.v 100%[===================>] 650.22M  46.6MB/s    in 13s
#
# 2020-02-20 09:56:08 (50.8 MB/s) - ‘wiki-news-300d-1M.vec.zip’ saved [681808098/681808098]

# %%
iu1 = np.triu_indices(4)

# %%
for i, j in zip(*np.triu_indices(4, k=1)):
  print(i, j)
# Out:
# 0 1
# 0 2
# 0 3
# 1 2
# 1 3
# 2 3
